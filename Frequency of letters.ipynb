# %%
def most_frequency(string):
    d=dict()
    for key in string:
        if key not in d:
            d[key]=1
        else:
            d[key]+=1
    return d

f=most_frequency("missippi")
d = dict(sorted(f.items(),reverse=True))
print(d)
# Out:
# {'s': 2, 'p': 2, 'm': 1, 'i': 3}
